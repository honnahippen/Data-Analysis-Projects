# %%
from IPython.display import Image

image_path = '/content/screenshot1.png'
Image(filename=image_path)

# %%
image_path = '/content/screenshot2.png'
Image(filename=image_path)

# %%
image_path = '/content/screenshot3.png'
Image(filename=image_path)

# %%
image_path = '/content/screenshot4.png'
Image(filename=image_path)
